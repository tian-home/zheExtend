# %%
import pandas as pd

# %%
df_city = pd.read_excel(
                    r"D:\tianxingzhe\Excel-田\train\df_world.xlsx",
                    sheet_name="city"
                   )

# %%
df_country = pd.read_excel(
                    r"D:\tianxingzhe\Excel-田\train\df_world.xlsx",
                    sheet_name="country"
                   )

# %%
df_city.head()
# Out:
#    ID            Name CountryCode       District  Population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200

# %%
df_country.head()
# Out:
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
# 2  AGO       Angola         Africa             Central Africa    1246700.0
# 3  AIA     Anguilla  North America                  Caribbean         96.0
# 4  ALB      Albania         Europe            Southern Europe      28748.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
# 2     1975.0    12878000            38.3  6648.0  7984.0
# 3        NaN        8000            76.1    63.2     NaN
# 4     1912.0     3401200            71.6  3205.0  2500.0
#
#                LocalName                                GovernmentForm  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# ...

# %%
df_city = df_city[["ID", "Name", "CountryCode"]]

# %%
df_city.head(2)
# Out:
#    ID      Name CountryCode
# 0   1     Kabul         AFG
# 1   2  Qandahar         AFG

# %%
df_merge = pd.merge(left=df_city, right=df_country, left_on="CountryCode", right_on="Code")

# %%
df_merge.head()
# Out:
#    ID          Name_x CountryCode Code       Name_y Continent  \
# 0   1           Kabul         AFG  AFG  Afghanistan      Asia
# 1   2        Qandahar         AFG  AFG  Afghanistan      Asia
# 2   3           Herat         AFG  AFG  Afghanistan      Asia
# 3   4  Mazar-e-Sharif         AFG  AFG  Afghanistan      Asia
# 4   5       Amsterdam         NLD  NLD  Netherlands    Europe
#
#                       Region  SurfaceArea  IndepYear  Population  \
# 0  Southern and Central Asia     652090.0     1919.0    22720000
# 1  Southern and Central Asia     652090.0     1919.0    22720000
# 2  Southern and Central Asia     652090.0     1919.0    22720000
# 3  Southern and Central Asia     652090.0     1919.0    22720000
# 4             Western Europe      41526.0     1581.0    15864000
#
#    LifeExpectancy       GNP    GNPOld              LocalName  \
# 0            45.9    5976.0       NaN  Afganistan/Afqanestan
# 1            45.9    5976.0       NaN  Afganistan/Afqanestan
# ...

# %%
df_merge.columns
# Out:
# Index(['ID', 'Name_x', 'CountryCode', 'Code', 'Name_y', 'Continent', 'Region',
#        'SurfaceArea', 'IndepYear', 'Population', 'LifeExpectancy', 'GNP',
#        'GNPOld', 'LocalName', 'GovernmentForm', 'HeadOfState', 'Capital',
#        'Code2'],
#       dtype='object')

# %%
new_columns = df_merge.columns.to_list()

# %%
new_columns
# Out:
# ['ID',
#  'Name_x',
#  'CountryCode',
#  'Code',
#  'Name_y',
#  'Continent',
#  'Region',
#  'SurfaceArea',
#  'IndepYear',
#  'Population',
#  'LifeExpectancy',
#  'GNP',
#  'GNPOld',
#  'LocalName',
#  'GovernmentForm',
#  'HeadOfState',
#  'Capital',
#  'Code2']
