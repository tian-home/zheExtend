# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel("./data/全球超市订单数据.xlsx")
df
# Out:
#         行 ID                     订单 ID       订购日期       装运日期 装运方式  \
# 0      40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   一级
# 1      26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07   二级
# 2      25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   一级
# 3      13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   一级
# 4      47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06   当日
# ...      ...                       ...        ...        ...  ...
# 51285  29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19   当日
# 51286  34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  标准级
# 51287  31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31   二级
# 51288   9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  标准级
# 51289   6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26   二级
#
#               客户 ID                客户名称   细分市场  邮政编码 (Postal Code)  \
# 0      AB-100151402       Aaron Bergman    消费者             73120.0
# ...

# %%
df.set_index(pd.to_datetime(df["订购日期"]), inplace=True)

# %%
df.head()
# Out:
#              行 ID                     订单 ID       订购日期       装运日期 装运方式  \
# 订购日期
# 2014-11-11  40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   一级
# 2014-02-05  26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07   二级
# 2014-10-17  25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   一级
# 2014-01-28  13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   一级
# 2014-11-05  47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06   当日
#
#                    客户 ID              客户名称   细分市场  邮政编码 (Postal Code)  \
# 订购日期
# 2014-11-11  AB-100151402     Aaron Bergman    消费者             73120.0
# 2014-02-05     JR-162107     Justin Ritter     公司                 NaN
# 2014-10-17     CR-127307      Craig Reiter    消费者                 NaN
# 2014-01-28    KM-1637548  Katherine Murray  家庭办公室                 NaN
# 2014-11-05    RH-9495111       Rick Hansen    消费者                 NaN
#
#                 城市 (City)  ...  子类别  \
# 订购日期                       ...
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2014-11-11', '2014-02-05', '2014-10-17', '2014-01-28',
#                '2014-11-05', '2014-06-28', '2012-11-06', '2013-04-14',
#                '2014-11-11', '2012-03-06',
#                ...
#                '2014-07-09', '2015-06-09', '2015-08-05', '2015-05-30',
#                '2013-12-28', '2015-06-19', '2014-05-06', '2012-08-26',
#                '2013-02-17', '2013-05-22'],
#               dtype='datetime64[ns]', name='订购日期', length=51290, freq=None)

# %%
df.index[0]
# Out:
# Timestamp('2014-11-11 00:00:00')

# %%
df.loc["2014-11-11":"2015-01-01"]
# Out:
#              行 ID                     订单 ID       订购日期       装运日期 装运方式  \
# 订购日期
# 2014-11-11  40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   一级
# 2014-11-11  40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   一级
# 2014-12-18  42336    MZ-2014-DG330087-41991 2014-12-18 2014-12-18   当日
# 2014-11-24  16988   ES-2014-BE1141048-41967 2014-11-24 2014-11-25   一级
# 2014-11-23  45616     MO-2014-AB25586-41966 2014-11-23 2014-11-23   当日
# ...           ...                       ...        ...        ...  ...
# 2014-12-30   2067   US-2014-GB1457598-42003 2014-12-30 2015-01-01   二级
# 2014-12-02   9285   MX-2014-MC1760593-41975 2014-12-02 2014-12-04   二级
# 2014-11-19   4488   MX-2014-SJ2050051-41962 2014-11-19 2014-11-25  标准级
# 2014-11-15  10196   US-2014-RS1987018-41958 2014-11-15 2014-11-19   二级
# 2014-12-16   3569   US-2014-GK1462036-41989 2014-12-16 2014-12-18   二级
#
#                    客户 ID                  客户名称   细分市场  邮政编码 (Postal Code)  \
# 订购日期
# ...

# %%
df.loc["2014-11":"2014-12"]
# Out:
#              行 ID                     订单 ID       订购日期       装运日期 装运方式  \
# 订购日期
# 2014-11-11  40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   一级
# 2014-11-05  47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06   当日
# 2014-11-11  40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   一级
# 2014-12-18  42336    MZ-2014-DG330087-41991 2014-12-18 2014-12-18   当日
# 2014-11-24  16988   ES-2014-BE1141048-41967 2014-11-24 2014-11-25   一级
# ...           ...                       ...        ...        ...  ...
# 2014-11-04  35777  CA-2014-XP21865140-41947 2014-11-04 2014-11-09  标准级
# 2014-11-04  35782  CA-2014-XP21865140-41947 2014-11-04 2014-11-09  标准级
# 2014-11-09   7940   US-2014-KM1637555-41952 2014-11-09 2014-11-10   一级
# 2014-11-15  10196   US-2014-RS1987018-41958 2014-11-15 2014-11-19   二级
# 2014-12-16   3569   US-2014-GK1462036-41989 2014-12-16 2014-12-18   二级
#
#                    客户 ID              客户名称   细分市场  邮政编码 (Postal Code)  \
# 订购日期
# ...

# %%
df.loc["2014-11":"2014-12"].index
# Out:
# DatetimeIndex(['2014-11-11', '2014-11-05', '2014-11-11', '2014-12-18',
#                '2014-11-24', '2014-11-23', '2014-12-12', '2014-12-02',
#                '2014-11-27', '2014-12-26',
#                ...
#                '2014-11-19', '2014-11-04', '2014-11-04', '2014-11-02',
#                '2014-11-04', '2014-11-04', '2014-11-04', '2014-11-09',
#                '2014-11-15', '2014-12-16'],
#               dtype='datetime64[ns]', name='订购日期', length=3198, freq=None)

# %%
df.loc["2014"]
# Out:
#              行 ID                     订单 ID       订购日期       装运日期 装运方式  \
# 订购日期
# 2014-11-11  40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   一级
# 2014-02-05  26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07   二级
# 2014-10-17  25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   一级
# 2014-01-28  13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   一级
# 2014-11-05  47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06   当日
# ...           ...                       ...        ...        ...  ...
# 2014-04-04  37195  CA-2014-ZD21925140-41733 2014-04-04 2014-04-10  标准级
# 2014-04-04  37194  CA-2014-ZD21925140-41733 2014-04-04 2014-04-10  标准级
# 2014-09-30   5596   MX-2014-SS2041082-41912 2014-09-30 2014-10-02   二级
# 2014-07-09  35112  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09   当日
# 2014-05-06  34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  标准级
#
#                    客户 ID                客户名称   细分市场  邮政编码 (Postal Code)  \
# 订购日期
# ...

# %%
df.loc["2014"].index
# Out:
# DatetimeIndex(['2014-11-11', '2014-02-05', '2014-10-17', '2014-01-28',
#                '2014-11-05', '2014-06-28', '2014-11-11', '2014-06-06',
#                '2014-02-27', '2014-08-22',
#                ...
#                '2014-03-21', '2014-07-26', '2014-07-26', '2014-08-19',
#                '2014-07-09', '2014-04-04', '2014-04-04', '2014-09-30',
#                '2014-07-09', '2014-05-06'],
#               dtype='datetime64[ns]', name='订购日期', length=13799, freq=None)

# %%
df.index.week
# Out:
# Int64Index([46,  6, 42,  5, 45, 26, 45, 15, 46, 10,
#             ...
#             28, 24, 32, 22, 52, 25, 19, 34,  7, 21],
#            dtype='int64', name='订购日期', length=51290)

# %%
df.index.month
# Out:
# Int64Index([11,  2, 10,  1, 11,  6, 11,  4, 11,  3,
#             ...
#              7,  6,  8,  5, 12,  6,  5,  8,  2,  5],
#            dtype='int64', name='订购日期', length=51290)

# %%
df.index.quarter
# Out:
# Int64Index([4, 1, 4, 1, 4, 2, 4, 2, 4, 1,
#             ...
#             3, 2, 3, 2, 4, 2, 2, 3, 1, 2],
#            dtype='int64', name='订购日期', length=51290)

# %%
df.groupby(df.index.week)["订购日期"].max().head()
# Out:
# 订购日期
# 1   2015-01-04
# 2   2015-01-11
# 3   2015-01-18
# 4   2015-01-25
# 5   2015-02-01
# Name: 订购日期, dtype: datetime64[ns]

# %%
df.groupby(df.index.week)["订购日期"].max().plot()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 35746 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26399 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 35746 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...
