# %%
import pandas as pd

# %%
df = pd.read_excel("./data/全球超市订单数据.xlsx")
df.head()
# Out:
#     行 ID                     订单 ID       订购日期       装运日期 装运方式         客户 ID  \
# 0  40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   一级  AB-100151402
# 1  26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07   二级     JR-162107
# 2  25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   一级     CR-127307
# 3  13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   一级    KM-1637548
# 4  47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06   当日    RH-9495111
#
#                客户名称   细分市场  邮政编码 (Postal Code)      城市 (City)  ...  子类别  \
# 0     Aaron Bergman    消费者             73120.0  Oklahoma City  ...   电话
# 1     Justin Ritter     公司                 NaN     Wollongong  ...   椅子
# 2      Craig Reiter    消费者                 NaN       Brisbane  ...   电话
# 3  Katherine Murray  家庭办公室                 NaN             柏林  ...   电话
# 4       Rick Hansen    消费者                 NaN            达喀尔  ...  复印机
#
#                                         产品名称       销售额 数量   折扣        利润  \
# ...

# %%
df.dtypes
# Out:
# 行 ID                                 int64
# 订单 ID                               object
# 订购日期                        datetime64[ns]
# 装运日期                        datetime64[ns]
# 装运方式                                object
# 客户 ID                               object
# 客户名称                                object
# 细分市场                                object
# 邮政编码 (Postal Code)                 float64
# 城市 (City)                           object
# 省/市/自治区 (State/Province)            object
# 国家/地区 (Country)                     object
# 地区                                  object
# 市场                                  object
# 产品 ID                               object
# 类别                                  object
# 子类别                                 object
# 产品名称                                object
# 销售额                                float64
# 数量                                   int64
# 折扣                                 float64
# 利润                                 float64
# ...

# %%
df["类别"].str

# %%
df["类别"].str.isnumeric()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: 类别, Length: 51290, dtype: bool

# %%
condition = df["客户 ID"].str.startswith("AB")

# %%
condition
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: 客户 ID, Length: 51290, dtype: bool

# %%
condition = df[df["客户 ID"].str.startswith("AB")]

# %%
condition
# Out:
#         行 ID                     订单 ID       订购日期       装运日期 装运方式  \
# 0      40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   一级
# 8      40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   一级
# 9      36258  CA-2012-AB10015140-40974 2012-03-06 2012-03-07   一级
# 10     36259  CA-2012-AB10015140-40974 2012-03-06 2012-03-07   一级
# 16     39519  CA-2012-AB10015140-40958 2012-02-19 2012-02-25  标准级
# ...      ...                       ...        ...        ...  ...
# 50033  13608   IT-2015-AB1001548-42074 2015-03-11 2015-03-11   当日
# 50133  45611     MO-2014-AB25586-41966 2014-11-23 2014-11-23   当日
# 50340  42683  ZA-2013-AB10060147-41509 2013-08-23 2013-08-24   一级
# 50622  50150  TU-2015-AB10060134-42236 2015-08-20 2015-08-26  标准级
# 51012    425   MX-2013-AB1025518-41637 2013-12-29 2014-01-05  标准级
#
#               客户 ID                  客户名称   细分市场  邮政编码 (Postal Code)  \
# 0      AB-100151402         Aaron Bergman    消费者             73120.0
# ...

# %%
df["客户 ID"].str.replace("-","#").str.slice(0,4)
# Out:
# 0        AB#1
# 1        JR#1
# 2        CR#1
# 3        KM#1
# 4        RH#9
#          ...
# 51285    KE#1
# 51286    ZD#2
# 51287    ZD#2
# 51288    RB#1
# 51289    MC#1
# Name: 客户 ID, Length: 51290, dtype: object

# %%
df["客户 ID"].str.replace("-","#").str[0:4]
# Out:
# 0        AB#1
# 1        JR#1
# 2        CR#1
# 3        KM#1
# 4        RH#9
#          ...
# 51285    KE#1
# 51286    ZD#2
# 51287    ZD#2
# 51288    RB#1
# 51289    MC#1
# Name: 客户 ID, Length: 51290, dtype: object
