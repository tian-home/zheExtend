# %% [markdown]
# # 0.读取数据

# %%
import pandas as pd

# %%
df_raw = pd.read_excel('./data/全球超市订单数据.xlsx')

# %%
df = df_raw.head(1000)
df
# Out:
#       行 ID                     订单 ID       订购日期       装运日期 装运方式         客户 ID  \
# 0    40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   一级  AB-100151402
# 1    26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07   二级     JR-162107
# 2    25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   一级     CR-127307
# 3    13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   一级    KM-1637548
# 4    47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06   当日    RH-9495111
# ..     ...                       ...        ...        ...  ...           ...
# 995  24278   IN-2015-JF1541527-42095 2015-04-01 2015-04-05  标准级    JF-1541527
# 996  36249  CA-2015-AS10225140-42347 2015-12-09 2015-12-13   二级  AS-102251404
# 997  30517   IN-2014-CK1259592-41929 2014-10-17 2014-10-19   二级    CK-1259592
# 998   1408   MX-2014-SS2014018-41658 2014-01-19 2014-01-26  标准级    SS-2014018
# 999  20944  ID-2015-RP19855130-42348 2015-12-10 2015-12-14  标准级   RP-19855130
#
# ...

# %%
df.index
# Out:
# Index(['AB-100151402', 'JR-162107', 'CR-127307', 'KM-1637548', 'RH-9495111',
#        'JM-156557', 'TS-2134092', 'MB-1808592', 'AB-100151402', 'AB-100151404',
#        ...
#        'AS-102251408', 'PB-19210127', 'AS-102251404', 'FO-1430545',
#        'SV-10815126', 'JF-1541527', 'AS-102251404', 'CK-1259592', 'SS-2014018',
#        'RP-19855130'],
#       dtype='object', name='客户 ID', length=1000)

# %%
df.dtypes
# Out:
# 行 ID                                 int64
# 订单 ID                               object
# 订购日期                        datetime64[ns]
# 装运日期                        datetime64[ns]
# 装运方式                                object
# 客户名称                                object
# 细分市场                                object
# 邮政编码 (Postal Code)                 float64
# 城市 (City)                           object
# 省/市/自治区 (State/Province)            object
# 国家/地区 (Country)                     object
# 地区                                  object
# 市场                                  object
# 产品 ID                               object
# 类别                                  object
# 子类别                                 object
# 产品名称                                object
# 销售额                                float64
# 数量                                   int64
# 折扣                                 float64
# 利润                                 float64
# 装运成本                               float64
# ...

# %% [markdown]
# # 1.使用单个label的值查询数据

# %%
df.loc['AB-100151402', '订购日期']
# Out:
# 客户 ID
# AB-100151402   2014-11-11
# AB-100151402   2014-11-11
# AB-100151402   2012-02-19
# Name: 订购日期, dtype: datetime64[ns]

# %% [markdown]
# # 2.使用值列表批量查询

# %%
df.loc[['AB-100151402','AS-102251404','JF-1541527'], '订购日期']
# Out:
# 客户 ID
# AB-100151402   2014-11-11
# AB-100151402   2014-11-11
# AB-100151402   2012-02-19
# AS-102251404   2015-09-18
# AS-102251404   2015-09-18
# AS-102251404   2015-12-09
# JF-1541527     2015-04-01
# Name: 订购日期, dtype: datetime64[ns]

# %%
df.loc[['AB-100151402','AS-102251404','JF-1541527'], ['订购日期', '装运日期']]
# Out:
#                    订购日期       装运日期
# 客户 ID
# AB-100151402 2014-11-11 2014-11-13
# AB-100151402 2014-11-11 2014-11-13
# AB-100151402 2012-02-19 2012-02-25
# AS-102251404 2015-09-18 2015-09-22
# AS-102251404 2015-09-18 2015-09-22
# AS-102251404 2015-12-09 2015-12-13
# JF-1541527   2015-04-01 2015-04-05

# %% [markdown]
# # 3.使用数值区间进行范围查询

# %% [markdown]
# # 4.使用条件表达式查询

# %%
df.loc[df["销售额"]>1000, :]
# Out:
#       行 ID                     订单 ID       订购日期       装运日期 装运方式        客户 ID  \
# 1    26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07   二级    JR-162107
# 2    25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   一级    CR-127307
# 3    13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   一级   KM-1637548
# 4    47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06   当日   RH-9495111
# 5    22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01   二级    JM-156557
# ..     ...                       ...        ...        ...  ...          ...
# 989  19853   ES-2013-LR1691544-41537 2013-09-20 2013-09-25   二级   LR-1691544
# 994  47959  SY-2013-SV10815126-41541 2013-09-24 2013-09-28  标准级  SV-10815126
# 995  24278   IN-2015-JF1541527-42095 2015-04-01 2015-04-05  标准级   JF-1541527
# 998   1408   MX-2014-SS2014018-41658 2014-01-19 2014-01-26  标准级   SS-2014018
# 999  20944  ID-2015-RP19855130-42348 2015-12-10 2015-12-14  标准级  RP-19855130
#
# ...

# %%
df["销售额"]>1000
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999     True
# Name: 销售额, Length: 1000, dtype: bool

# %%
df[df["销售额"]>1000]
# Out:
#       行 ID                     订单 ID       订购日期       装运日期 装运方式        客户 ID  \
# 1    26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07   二级    JR-162107
# 2    25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   一级    CR-127307
# 3    13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   一级   KM-1637548
# 4    47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06   当日   RH-9495111
# 5    22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01   二级    JM-156557
# ..     ...                       ...        ...        ...  ...          ...
# 989  19853   ES-2013-LR1691544-41537 2013-09-20 2013-09-25   二级   LR-1691544
# 994  47959  SY-2013-SV10815126-41541 2013-09-24 2013-09-28  标准级  SV-10815126
# 995  24278   IN-2015-JF1541527-42095 2015-04-01 2015-04-05  标准级   JF-1541527
# 998   1408   MX-2014-SS2014018-41658 2014-01-19 2014-01-26  标准级   SS-2014018
# 999  20944  ID-2015-RP19855130-42348 2015-12-10 2015-12-14  标准级  RP-19855130
#
# ...

# %%
df.loc[(df["细分市场"]=='公司') & (df["销售额"]>=1000)]
# Out:
#       行 ID                     订单 ID       订购日期       装运日期 装运方式         客户 ID  \
# 1    26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07   二级     JR-162107
# 5    22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01   二级     JM-156557
# 11   28879    ID-2013-AJ107801-41383 2013-04-19 2013-04-22   一级     AJ-107801
# 15   13779   ES-2015-BP1118545-42216 2015-07-31 2015-08-03   二级    BP-1118545
# 17   12069   ES-2015-PJ1883564-42255 2015-09-08 2015-09-14  标准级    PJ-1883564
# ..     ...                       ...        ...        ...  ...           ...
# 974  33951  CA-2015-AS10225140-42265 2015-09-18 2015-09-22   二级  AS-102251404
# 980    424   MX-2015-LS1720080-42294 2015-10-17 2015-10-20   一级    LS-1720080
# 994  47959  SY-2013-SV10815126-41541 2013-09-24 2013-09-28  标准级   SV-10815126
# 998   1408   MX-2014-SS2014018-41658 2014-01-19 2014-01-26  标准级    SS-2014018
# 999  20944  ID-2015-RP19855130-42348 2015-12-10 2015-12-14  标准级   RP-19855130
#
# ...

# %%
(df["细分市场"]=='公司') & (df["销售额"]>=1000)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %% [markdown]
# # 5.调用函数查询

# %%
df.loc[lambda df : (df["细分市场"]=='公司') & (df["销售额"]>=1000), :]
# Out:
#       行 ID                     订单 ID       订购日期       装运日期 装运方式         客户 ID  \
# 1    26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07   二级     JR-162107
# 5    22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01   二级     JM-156557
# 11   28879    ID-2013-AJ107801-41383 2013-04-19 2013-04-22   一级     AJ-107801
# 15   13779   ES-2015-BP1118545-42216 2015-07-31 2015-08-03   二级    BP-1118545
# 17   12069   ES-2015-PJ1883564-42255 2015-09-08 2015-09-14  标准级    PJ-1883564
# ..     ...                       ...        ...        ...  ...           ...
# 974  33951  CA-2015-AS10225140-42265 2015-09-18 2015-09-22   二级  AS-102251404
# 980    424   MX-2015-LS1720080-42294 2015-10-17 2015-10-20   一级    LS-1720080
# 994  47959  SY-2013-SV10815126-41541 2013-09-24 2013-09-28  标准级   SV-10815126
# 998   1408   MX-2014-SS2014018-41658 2014-01-19 2014-01-26  标准级    SS-2014018
# 999  20944  ID-2015-RP19855130-42348 2015-12-10 2015-12-14  标准级   RP-19855130
#
# ...
